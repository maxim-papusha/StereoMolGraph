# %% [markdown]
# # Comparing chiral Geometries
#
# StereoMolGraphs can be constructed from cartesian coordinates / xyz files.
# Relative location of atoms is extracted automatically.
# One challenging example of chiral molecules is Twistane. We show how to compare two enantiomers of twistane starting from their cartesian coordinates.
